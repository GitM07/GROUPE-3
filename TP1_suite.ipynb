# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/youss/Downloads/M2/data mining/ex1data2.txt",sep=",")

# %%
data.head()
# Out:
#    taille  nbr_chambres    prix
# 0    2104             3  399900
# 1    1600             3  329900
# 2    2400             3  369000
# 3    1416             2  232000
# 4    3000             4  539900

# %%
X = data.iloc[:,0]
Y = data.iloc[:,1]
Z = data.iloc[:,2]

# %%
X.head()
# Out:
# 0    2104
# 1    1600
# 2    2400
# 3    1416
# 4    3000
# Name: taille, dtype: int64

# %%
Y.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    2
# 4    4
# Name: nbr_chambres, dtype: int64

# %%
Z.head()
# Out:
# 0    399900
# 1    329900
# 2    369000
# 3    232000
# 4    539900
# Name: prix, dtype: int64

# %%
ax = plt.axes(projection ='3d')
ax.scatter(X, Y, Z, color='red')
ax.set_title('visualisation des 3 axes :')
plt.show()

# %%
def loss(Z, Z_predicted):
    n = y.count()
    loss = np.sum((Z - Z_predicted)**2) / n
    return loss

# %%
def gradient_descent(X, Y, Z, iterations = 1000, learning_rate= 0.01):
    w1 = 0.01
    w2 = 0.01
    b  = 0.01
    n  = len(X)
    previous_cost = None
    for i in range(iterations):
        Z_predicted = w1*X + w2*Y + b
        cost = loss(Z , Z_predicted)
        previous_cost = cost  
        w1_derv = -(2/n) * sum( X*(Z - Z_predicted) )
        w2_derv = -(2/n) * sum( Y*(Z - Z_predicted) )
        b_derv  = -(2/n) * sum(Z - Z_predicted)
        w1 = w1 - (learning_rate * w1_derv)
        w2 = w2 - (learning_rate * w2_derv)
        b = b - (learning_rate * b_derv)
        print(f" Iteration {i}: l'erreur : {cost},  w1 : {w1},  w2 : {w2}, b : {b}")
    return w1,w2,b

# %%
w1,w2,b = gradient_descent(X, Y, Z, iterations = 300, learning_rate= 0.0000001)
# Out:
#  Iteration 0: l'erreur : 131167783278.5644,  w1 : 152.8425666120426,  w2 : 0.23406016480851066, b : 0.07807852221276597
#  Iteration 1: l'erreur : 5522388807.336398,  w1 : 164.43188761222606,  w2 : 0.2541182504169321, b : 0.08500305085821835
#  Iteration 2: l'erreur : 4799899835.988036,  w1 : 165.3107031073428,  w2 : 0.2587068140561789, b : 0.08729025888070541
#  Iteration 3: l'erreur : 4795745218.816269,  w1 : 165.37733868067295,  w2 : 0.26212231983934076, b : 0.0892258176698666
#  Iteration 4: l'erreur : 4795721183.160617,  w1 : 165.38238647693413,  w2 : 0.2654488716959397, b : 0.09113471060322778
#  Iteration 5: l'erreur : 4795720899.262911,  w1 : 165.38276405889704,  w2 : 0.26876867745867555, b : 0.09304158123977097
#  Iteration 6: l'erreur : 4795720751.943129,  w1 : 165.38278749751257,  w2 : 0.27208797096507376, b : 0.09494829830584132
#  Iteration 7: l'erreur : 4795720605.408759,  w1 : 165.38278408136347,  w2 : 0.2754072249283665, b : 0.09685500350735708
# ...

# %%
Z_predicted = w1*X + w2*Y + b
ax = plt.axes(projection ='3d')
ax.scatter(X, Y, Z, color='red')
ax.set_title('visualisation des 3 axes :')
plt.plot([min(X), max(X)],[min(Y), max(Y)], [min(Z_predicted), max(Z_predicted)] , color='blue')
plt.show()
